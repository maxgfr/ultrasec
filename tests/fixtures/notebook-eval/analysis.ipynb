# %% [markdown]
# # Event analysis
# Pulls raw event names out of the analytics warehouse.

# %%
# %matplotlib inline
# !pip install pandas
import pandas as pd
import os

# %%
def load_events(conn):
    return pd.read_sql('select action_eventname from log_link_visit_action', conn)

# %%
df = load_events(conn)
parsed = df['action_eventname'].apply(eval)
os.system('echo ' + parsed.iloc[0])
